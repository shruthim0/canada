# %% [markdown]
# # Coin Flip Part 2

# %% [markdown]
# <!DOCTYPE html>
# <html>
# <body>
#
#
#
# <button type="button" id="flip" onclick="toggleBit()">FLIP</button>
# <p id="coin"></p>
#
# <script>
#
# let bits = "";
#     for(let i = 0; i < BITS; i++) {
#         bits = bits + document.getElementById('digit' + i).value;
#         }
#     return bits;
#
# const IMAGE_ON = "{{site.baseurl}}/images/HeadsOn.png";
# const IMAGE_OFF = "{{site.baseurl}}/images/TailsOn.png"
#
# function toggleBit(i) {
#     i == math.random(0,1)
#     const dig = document.getElementById(i);
#     // Change digit and visual
#     if (i==0) {
#         dig.value = 0;
#         image.src = IMAGE_OFF;
#     } else {
#         dig.value = 1;
#         image.src = IMAGE_ON;
#     }
#     var x = document.getElementById("flip").type;
#     document.getElementById("coin").innerHTML = x;
# }
# //function coinFlip() {
#  //   i = math.random(0,1)
# //    if (i==1) {
#         //img.src = IMAGE_ON
# //    } else {
#   //     img.src = IMAGE_OFF
#   //  }
#    // var x = document.getElementById("flip").type;
#    // document.getElementById("coin").innerHTML = x;
# //}
#
# </script>
#
# </body>
# </html>

# %%
import random

# importing Image class from PIL package
from PIL import Image
 
# creating a object
im = Image.open(r"images/HeadsOn.png")
image = Image.open(r"images/TailsOn.png")

i=random.randint(0,1)

if i == 1:
    print("heads")
    display(im)

else:
    print("tails")
    display(image)
# Out:
# heads
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=190x157>
